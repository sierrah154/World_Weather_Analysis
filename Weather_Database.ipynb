# %% [markdown]
# <h1><center>Module 6 Challenge</center></h1>

# %% [markdown]
# <h2><center>Part 1: Get the Weather Description and Amount of Precipitation for Each City</center></h2>

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the Latitude and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 615

# %%
# Import the request library.
import requests

from datetime import datetime
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data.
city_data = []

# Print to logger.
print('Beginning Data Retrieval')
print('-' * 25)

# Create a counter.
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data.
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Current Description': city_weather_description,
            'Rain (inches)': city_rain_inches,
            'Snow (inches)': city_snow_inches,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country
        })
    except:
        print('City not found. Skipping...')
        pass
# Indicate that the Data Loading is complete.
print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | zhezkazgan
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | nanortalik
# Processing Record 6 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 1 | klaksvik
# Processing Record 8 of Set 1 | rzhaksa
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | esperance
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | hami
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | clyde river
# Processing Record 17 of Set 1 | simoes
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | thinadhoo
# Processing Record 20 of Set 1 | gorontalo
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | musoma
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | aquiraz
# Processing Record 26 of Set 1 | tuatapere
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | peno
# Processing Record 29 of Set 1 | sitka
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | kahului
# Processing Record 33 of Set 1 | bathsheba
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | pilar
# Processing Record 36 of Set 1 | baker city
# Processing Record 37 of Set 1 | somerville
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | guerrero negro
# Processing Record 40 of Set 1 | grindavik
# Processing Record 41 of Set 1 | lata
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | kidal
# Processing Record 45 of Set 1 | igarka
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | usoke
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | caramay
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | murgab
# Processing Record 5 of Set 2 | teya
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | santarem
# Processing Record 9 of Set 2 | coquimbo
# Processing Record 10 of Set 2 | porto novo
# Processing Record 11 of Set 2 | yanam
# Processing Record 12 of Set 2 | bullhead city
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | katsuura
# Processing Record 16 of Set 2 | komsomolskiy
# Processing Record 17 of Set 2 | pangody
# Processing Record 18 of Set 2 | bulgan
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | ust-maya
# Processing Record 21 of Set 2 | tessalit
# Processing Record 22 of Set 2 | kavaratti
# Processing Record 23 of Set 2 | pacifica
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 2 | mataura
# Processing Record 27 of Set 2 | almenevo
# City not found. Skipping...
# Processing Record 28 of Set 2 | shenandoah
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | leningradskiy
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | almaznyy
# Processing Record 35 of Set 2 | pisco
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | novolvovsk
# City not found. Skipping...
# Processing Record 41 of Set 2 | meulaboh
# Processing Record 42 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 2 | bandarbeyla
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | jucas
# Processing Record 46 of Set 2 | port blair
# Processing Record 47 of Set 2 | clocolan
# Processing Record 48 of Set 2 | richards bay
# Processing Record 49 of Set 2 | alekseyevsk
# Processing Record 50 of Set 2 | jhargram
# Processing Record 1 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 3 | moranbah
# Processing Record 3 of Set 3 | tucuma
# Processing Record 4 of Set 3 | buraydah
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | morant bay
# Processing Record 7 of Set 3 | maun
# Processing Record 8 of Set 3 | colac
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | kodinsk
# Processing Record 11 of Set 3 | kendari
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | codrington
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | flin flon
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | ostrovnoy
# Processing Record 18 of Set 3 | roald
# Processing Record 19 of Set 3 | tagusao
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | pala
# Processing Record 22 of Set 3 | luderitz
# Processing Record 23 of Set 3 | dingli
# Processing Record 24 of Set 3 | barrow
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | atasu
# Processing Record 27 of Set 3 | torres
# Processing Record 28 of Set 3 | saint george
# Processing Record 29 of Set 3 | faanui
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | los llanos de aridane
# Processing Record 32 of Set 3 | vetluzhskiy
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | bengkulu
# Processing Record 35 of Set 3 | henties bay
# Processing Record 36 of Set 3 | borda da mata
# Processing Record 37 of Set 3 | emerald
# Processing Record 38 of Set 3 | olafsvik
# Processing Record 39 of Set 3 | isabela
# Processing Record 40 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 3 | makasar
# Processing Record 42 of Set 3 | tual
# Processing Record 43 of Set 3 | cururupu
# Processing Record 44 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 3 | aloja
# Processing Record 47 of Set 3 | riwaka
# Processing Record 48 of Set 3 | uige
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | ilulissat
# Processing Record 1 of Set 4 | aykhal
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | coihaique
# Processing Record 4 of Set 4 | iberia
# Processing Record 5 of Set 4 | laguna
# Processing Record 6 of Set 4 | hisor
# Processing Record 7 of Set 4 | berlevag
# Processing Record 8 of Set 4 | zonguldak
# Processing Record 9 of Set 4 | tarboro
# Processing Record 10 of Set 4 | cuautepec
# Processing Record 11 of Set 4 | cullman
# Processing Record 12 of Set 4 | kruisfontein
# Processing Record 13 of Set 4 | padang
# Processing Record 14 of Set 4 | lugus
# Processing Record 15 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 4 | bayburt
# Processing Record 17 of Set 4 | klyuchi
# Processing Record 18 of Set 4 | victoria point
# Processing Record 19 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 20 of Set 4 | bilibino
# Processing Record 21 of Set 4 | hithadhoo
# Processing Record 22 of Set 4 | juba
# Processing Record 23 of Set 4 | adrar
# Processing Record 24 of Set 4 | ust-nera
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | bethel
# Processing Record 27 of Set 4 | utevka
# Processing Record 28 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 4 | deori khas
# Processing Record 30 of Set 4 | san jose
# Processing Record 31 of Set 4 | ossora
# Processing Record 32 of Set 4 | grand forks
# Processing Record 33 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 34 of Set 4 | kibala
# Processing Record 35 of Set 4 | turtas
# Processing Record 36 of Set 4 | oranjestad
# Processing Record 37 of Set 4 | pasighat
# Processing Record 38 of Set 4 | akureyri
# Processing Record 39 of Set 4 | broken hill
# Processing Record 40 of Set 4 | epe
# Processing Record 41 of Set 4 | upernavik
# Processing Record 42 of Set 4 | kavieng
# Processing Record 43 of Set 4 | tura
# Processing Record 44 of Set 4 | torbay
# Processing Record 45 of Set 4 | margate
# Processing Record 46 of Set 4 | metro
# Processing Record 47 of Set 4 | pangnirtung
# Processing Record 48 of Set 4 | mocuba
# Processing Record 49 of Set 4 | vestmanna
# Processing Record 50 of Set 4 | tiarei
# Processing Record 1 of Set 5 | rock springs
# Processing Record 2 of Set 5 | kadoma
# Processing Record 3 of Set 5 | menongue
# Processing Record 4 of Set 5 | severo-yeniseyskiy
# Processing Record 5 of Set 5 | nouadhibou
# Processing Record 6 of Set 5 | mar del plata
# Processing Record 7 of Set 5 | roma
# Processing Record 8 of Set 5 | bereda
# Processing Record 9 of Set 5 | lompoc
# Processing Record 10 of Set 5 | mayya
# Processing Record 11 of Set 5 | mehran
# Processing Record 12 of Set 5 | liezen
# Processing Record 13 of Set 5 | norman wells
# Processing Record 14 of Set 5 | yeppoon
# Processing Record 15 of Set 5 | san cristobal
# Processing Record 16 of Set 5 | pringsewu
# Processing Record 17 of Set 5 | aketi
# Processing Record 18 of Set 5 | rafraf
# Processing Record 19 of Set 5 | pak phanang
# Processing Record 20 of Set 5 | diffa
# Processing Record 21 of Set 5 | ashtian
# Processing Record 22 of Set 5 | ust-kuyga
# Processing Record 23 of Set 5 | kenai
# Processing Record 24 of Set 5 | hamilton
# Processing Record 25 of Set 5 | orlik
# Processing Record 26 of Set 5 | sao joao da barra
# Processing Record 27 of Set 5 | mega
# Processing Record 28 of Set 5 | beloha
# Processing Record 29 of Set 5 | sorland
# Processing Record 30 of Set 5 | marigot
# Processing Record 31 of Set 5 | kysyl-syr
# Processing Record 32 of Set 5 | mbandaka
# Processing Record 33 of Set 5 | qaqortoq
# Processing Record 34 of Set 5 | kudahuvadhoo
# Processing Record 35 of Set 5 | mehamn
# Processing Record 36 of Set 5 | longyearbyen
# Processing Record 37 of Set 5 | maan
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | alto araguaia
# Processing Record 40 of Set 5 | collie
# Processing Record 41 of Set 5 | vostok
# Processing Record 42 of Set 5 | hakvik
# City not found. Skipping...
# Processing Record 43 of Set 5 | buenavista
# Processing Record 44 of Set 5 | nikolskoye
# Processing Record 45 of Set 5 | marzuq
# Processing Record 46 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 5 | taoudenni
# Processing Record 48 of Set 5 | rocha
# Processing Record 49 of Set 5 | hasaki
# Processing Record 50 of Set 5 | bubaque
# Processing Record 1 of Set 6 | bekhtery
# Processing Record 2 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 6 | black river
# Processing Record 4 of Set 6 | murud
# Processing Record 5 of Set 6 | coquimatlan
# Processing Record 6 of Set 6 | priiskovyy
# Processing Record 7 of Set 6 | tiznit
# Processing Record 8 of Set 6 | wysokie mazowieckie
# Processing Record 9 of Set 6 | xingcheng
# Processing Record 10 of Set 6 | coruripe
# Processing Record 11 of Set 6 | ewa beach
# Processing Record 12 of Set 6 | kibaha
# Processing Record 13 of Set 6 | edea
# Processing Record 14 of Set 6 | hirara
# Processing Record 15 of Set 6 | uruguaiana
# Processing Record 16 of Set 6 | buta
# Processing Record 17 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 6 | humaita
# Processing Record 19 of Set 6 | kachug
# Processing Record 20 of Set 6 | glens falls
# Processing Record 21 of Set 6 | shizunai
# Processing Record 22 of Set 6 | husavik
# Processing Record 23 of Set 6 | bilma
# Processing Record 24 of Set 6 | fukue
# Processing Record 25 of Set 6 | asandh
# Processing Record 26 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 27 of Set 6 | khatanga
# Processing Record 28 of Set 6 | bagotville
# Processing Record 29 of Set 6 | caravelas
# Processing Record 30 of Set 6 | hobyo
# Processing Record 31 of Set 6 | port said
# Processing Record 32 of Set 6 | cabo san lucas
# Processing Record 33 of Set 6 | portland
# Processing Record 34 of Set 6 | puerto cabezas
# Processing Record 35 of Set 6 | yian
# City not found. Skipping...
# Processing Record 36 of Set 6 | zenzeli
# Processing Record 37 of Set 6 | ulety
# Processing Record 38 of Set 6 | ugoofaaru
# Processing Record 39 of Set 6 | illapel
# Processing Record 40 of Set 6 | victoria
# Processing Record 41 of Set 6 | sao desiderio
# Processing Record 42 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 6 | gat
# Processing Record 44 of Set 6 | warrnambool
# Processing Record 45 of Set 6 | farmington
# Processing Record 46 of Set 6 | san patricio
# Processing Record 47 of Set 6 | chokurdakh
# Processing Record 48 of Set 6 | caronport
# Processing Record 49 of Set 6 | pavlodar
# Processing Record 50 of Set 6 | sangar
# Processing Record 1 of Set 7 | poum
# Processing Record 2 of Set 7 | santa rosa del sur
# Processing Record 3 of Set 7 | linhares
# Processing Record 4 of Set 7 | saint-pierre
# Processing Record 5 of Set 7 | neiafu
# Processing Record 6 of Set 7 | solnechnyy
# Processing Record 7 of Set 7 | agadez
# Processing Record 8 of Set 7 | resistencia
# Processing Record 9 of Set 7 | matay
# Processing Record 10 of Set 7 | togur
# Processing Record 11 of Set 7 | zhangjiakou
# Processing Record 12 of Set 7 | vallenar
# Processing Record 13 of Set 7 | cherskiy
# Processing Record 14 of Set 7 | goya
# Processing Record 15 of Set 7 | semme
# Processing Record 16 of Set 7 | lagoa
# Processing Record 17 of Set 7 | viedma
# Processing Record 18 of Set 7 | saint anthony
# Processing Record 19 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 7 | salalah
# Processing Record 21 of Set 7 | mahibadhoo
# Processing Record 22 of Set 7 | imbituba
# Processing Record 23 of Set 7 | harrisonburg
# Processing Record 24 of Set 7 | monywa
# Processing Record 25 of Set 7 | lipin bor
# Processing Record 26 of Set 7 | charagua
# Processing Record 27 of Set 7 | worland
# Processing Record 28 of Set 7 | vaitape
# Processing Record 29 of Set 7 | kanniyakumari
# Processing Record 30 of Set 7 | bambous virieux
# Processing Record 31 of Set 7 | kleck
# City not found. Skipping...
# Processing Record 32 of Set 7 | labuhan
# Processing Record 33 of Set 7 | camopi
# Processing Record 34 of Set 7 | langsa
# Processing Record 35 of Set 7 | zhigansk
# Processing Record 36 of Set 7 | grand gaube
# Processing Record 37 of Set 7 | nyurba
# Processing Record 38 of Set 7 | marinette
# Processing Record 39 of Set 7 | pombia
# Processing Record 40 of Set 7 | albanel
# Processing Record 41 of Set 7 | minot
# Processing Record 42 of Set 7 | eldama ravine
# Processing Record 43 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 7 | vardo
# Processing Record 45 of Set 7 | mazyr
# Processing Record 46 of Set 7 | erzin
# Processing Record 47 of Set 7 | vung tau
# Processing Record 48 of Set 7 | sulangan
# Processing Record 49 of Set 7 | tecoanapa
# Processing Record 50 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 8 | praia
# Processing Record 2 of Set 8 | saint-augustin
# Processing Record 3 of Set 8 | avera
# Processing Record 4 of Set 8 | havre-saint-pierre
# Processing Record 5 of Set 8 | kasongo
# Processing Record 6 of Set 8 | souillac
# Processing Record 7 of Set 8 | yumen
# Processing Record 8 of Set 8 | cidreira
# Processing Record 9 of Set 8 | marienburg
# Processing Record 10 of Set 8 | gimli
# Processing Record 11 of Set 8 | alice springs
# Processing Record 12 of Set 8 | trinidad
# Processing Record 13 of Set 8 | torrington
# Processing Record 14 of Set 8 | kralendijk
# Processing Record 15 of Set 8 | bowen
# Processing Record 16 of Set 8 | alyangula
# Processing Record 17 of Set 8 | vysokogornyy
# Processing Record 18 of Set 8 | belawan
# Processing Record 19 of Set 8 | sisimiut
# Processing Record 20 of Set 8 | guarenas
# Processing Record 21 of Set 8 | tigil
# Processing Record 22 of Set 8 | moyale
# Processing Record 23 of Set 8 | boulder city
# Processing Record 24 of Set 8 | kalmunai
# Processing Record 25 of Set 8 | janakpur road
# City not found. Skipping...
# Processing Record 26 of Set 8 | nioki
# Processing Record 27 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 28 of Set 8 | yerofey pavlovich
# Processing Record 29 of Set 8 | san fernando
# Processing Record 30 of Set 8 | isangel
# Processing Record 31 of Set 8 | tabas
# Processing Record 32 of Set 8 | bongandanga
# Processing Record 33 of Set 8 | reforma
# Processing Record 34 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 8 | kitimat
# Processing Record 36 of Set 8 | rawson
# Processing Record 37 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 8 | la ronge
# Processing Record 39 of Set 8 | rio gallegos
# Processing Record 40 of Set 8 | christchurch
# Processing Record 41 of Set 8 | antofagasta
# Processing Record 42 of Set 8 | ribeira grande
# Processing Record 43 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 8 | tautira
# Processing Record 45 of Set 8 | sioux lookout
# Processing Record 46 of Set 8 | teguise
# Processing Record 47 of Set 8 | vao
# Processing Record 48 of Set 8 | denpasar
# Processing Record 49 of Set 8 | concepcion del oro
# Processing Record 50 of Set 8 | urmary
# Processing Record 1 of Set 9 | pacific grove
# Processing Record 2 of Set 9 | mormugao
# Processing Record 3 of Set 9 | hualmay
# Processing Record 4 of Set 9 | kano
# Processing Record 5 of Set 9 | comodoro rivadavia
# Processing Record 6 of Set 9 | doha
# Processing Record 7 of Set 9 | nolinsk
# Processing Record 8 of Set 9 | mecca
# Processing Record 9 of Set 9 | flinders
# Processing Record 10 of Set 9 | gamba
# Processing Record 11 of Set 9 | hailey
# Processing Record 12 of Set 9 | rajaldesar
# Processing Record 13 of Set 9 | scarborough
# Processing Record 14 of Set 9 | balkhash
# Processing Record 15 of Set 9 | langres
# Processing Record 16 of Set 9 | yulara
# Processing Record 17 of Set 9 | nantucket
# Processing Record 18 of Set 9 | falam
# Processing Record 19 of Set 9 | vernon
# Processing Record 20 of Set 9 | abeche
# Processing Record 21 of Set 9 | presidente olegario
# Processing Record 22 of Set 9 | sikonge
# Processing Record 23 of Set 9 | beaune
# Processing Record 24 of Set 9 | bathurst
# Processing Record 25 of Set 9 | malanje
# Processing Record 26 of Set 9 | koulamoutou
# Processing Record 27 of Set 9 | trat
# Processing Record 28 of Set 9 | dongsheng
# Processing Record 29 of Set 9 | ahipara
# Processing Record 30 of Set 9 | taltal
# Processing Record 31 of Set 9 | cayenne
# Processing Record 32 of Set 9 | tromso
# Processing Record 33 of Set 9 | natal
# Processing Record 34 of Set 9 | ngong
# Processing Record 35 of Set 9 | meadville
# Processing Record 36 of Set 9 | teopisca
# Processing Record 37 of Set 9 | namatanai
# Processing Record 38 of Set 9 | cockburn town
# Processing Record 39 of Set 9 | paamiut
# Processing Record 40 of Set 9 | otradnoye
# Processing Record 41 of Set 9 | qingyuan
# Processing Record 42 of Set 9 | gladstone
# Processing Record 43 of Set 9 | narsaq
# Processing Record 44 of Set 9 | doka
# Processing Record 45 of Set 9 | ornskoldsvik
# Processing Record 46 of Set 9 | colares
# Processing Record 47 of Set 9 | kaitangata
# Processing Record 48 of Set 9 | carlsbad
# Processing Record 49 of Set 9 | allada
# Processing Record 50 of Set 9 | sambava
# Processing Record 1 of Set 10 | tilichiki
# Processing Record 2 of Set 10 | kara
# Processing Record 3 of Set 10 | brooks
# Processing Record 4 of Set 10 | craigieburn
# Processing Record 5 of Set 10 | san juan
# Processing Record 6 of Set 10 | shingu
# Processing Record 7 of Set 10 | beyneu
# Processing Record 8 of Set 10 | provideniya
# Processing Record 9 of Set 10 | alta floresta
# Processing Record 10 of Set 10 | novyy urgal
# Processing Record 11 of Set 10 | bonthe
# Processing Record 12 of Set 10 | kattivakkam
# Processing Record 13 of Set 10 | corning
# Processing Record 14 of Set 10 | bocana de paiwas
# Processing Record 15 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 10 | constitucion
# Processing Record 17 of Set 10 | handwara
# City not found. Skipping...
# Processing Record 18 of Set 10 | itarema
# Processing Record 19 of Set 10 | abashiri
# Processing Record 20 of Set 10 | mandalgovi
# Processing Record 21 of Set 10 | ambilobe
# Processing Record 22 of Set 10 | kita
# Processing Record 23 of Set 10 | mount gambier
# Processing Record 24 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 10 | port lincoln
# Processing Record 26 of Set 10 | kunya
# Processing Record 27 of Set 10 | muravlenko
# Processing Record 28 of Set 10 | lafia
# Processing Record 29 of Set 10 | auchtermuchty
# Processing Record 30 of Set 10 | xambioa
# Processing Record 31 of Set 10 | omsukchan
# Processing Record 32 of Set 10 | batavia
# Processing Record 33 of Set 10 | honningsvag
# Processing Record 34 of Set 10 | evinayong
# Processing Record 35 of Set 10 | vaasa
# Processing Record 36 of Set 10 | san quintin
# Processing Record 37 of Set 10 | wanning
# Processing Record 38 of Set 10 | high level
# Processing Record 39 of Set 10 | la palma
# Processing Record 40 of Set 10 | raudeberg
# Processing Record 41 of Set 10 | altamont
# Processing Record 42 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 10 | shellbrook
# Processing Record 44 of Set 10 | bima
# Processing Record 45 of Set 10 | kununurra
# Processing Record 46 of Set 10 | touros
# Processing Record 47 of Set 10 | lusambo
# Processing Record 48 of Set 10 | northam
# Processing Record 49 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 50 of Set 10 | visby
# Processing Record 1 of Set 11 | vilhena
# Processing Record 2 of Set 11 | kemise
# Processing Record 3 of Set 11 | acari
# Processing Record 4 of Set 11 | warmbad
# Processing Record 5 of Set 11 | belyy yar
# Processing Record 6 of Set 11 | roznava
# Processing Record 7 of Set 11 | sinnar
# Processing Record 8 of Set 11 | ankang
# Processing Record 9 of Set 11 | jizan
# Processing Record 10 of Set 11 | kalaleh
# Processing Record 11 of Set 11 | townsville
# Processing Record 12 of Set 11 | cantanhede
# Processing Record 13 of Set 11 | sola
# Processing Record 14 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 11 | krasnoselkup
# Processing Record 16 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 11 | deputatskiy
# Processing Record 18 of Set 11 | tadine
# Processing Record 19 of Set 11 | nyzy
# Processing Record 20 of Set 11 | faya
# Processing Record 21 of Set 11 | otavi
# Processing Record 22 of Set 11 | kosya
# City not found. Skipping...
# Processing Record 23 of Set 11 | igrim
# Processing Record 24 of Set 11 | gushikawa
# Processing Record 25 of Set 11 | poya
# Processing Record 26 of Set 11 | cajati
# Processing Record 27 of Set 11 | itacoatiara
# Processing Record 28 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 11 | gobabis
# Processing Record 30 of Set 11 | tiruppur
# Processing Record 31 of Set 11 | concordia
# Processing Record 32 of Set 11 | garachine
# Processing Record 33 of Set 11 | puerto escondido
# Processing Record 34 of Set 11 | pyay
# Processing Record 35 of Set 11 | port macquarie
# Processing Record 36 of Set 11 | chara
# Processing Record 37 of Set 11 | pirgos
# Processing Record 38 of Set 11 | karasuk
# Processing Record 39 of Set 11 | tibiri
# Processing Record 40 of Set 11 | stornoway
# Processing Record 41 of Set 11 | bhabua
# Processing Record 42 of Set 11 | plettenberg bay
# Processing Record 43 of Set 11 | taphan hin
# Processing Record 44 of Set 11 | vagay
# Processing Record 45 of Set 11 | polunochnoye
# Processing Record 46 of Set 11 | olinda
# Processing Record 47 of Set 11 | fontem
# Processing Record 48 of Set 11 | broome
# Processing Record 49 of Set 11 | port moresby
# Processing Record 50 of Set 11 | half moon bay
# Processing Record 1 of Set 12 | ortigueira
# Processing Record 2 of Set 12 | college
# Processing Record 3 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 12 | nelson bay
# Processing Record 5 of Set 12 | yazd
# Processing Record 6 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 12 | baru
# Processing Record 8 of Set 12 | toyooka
# Processing Record 9 of Set 12 | gaoua
# Processing Record 10 of Set 12 | russell
# Processing Record 11 of Set 12 | iquique
# Processing Record 12 of Set 12 | puerto madero
# Processing Record 13 of Set 12 | hay river
# Processing Record 14 of Set 12 | naliya
# Processing Record 15 of Set 12 | riaba
# City not found. Skipping...
# Processing Record 16 of Set 12 | kuldur
# Processing Record 17 of Set 12 | araouane
# Processing Record 18 of Set 12 | port-cartier
# Processing Record 19 of Set 12 | oga
# Processing Record 20 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 21 of Set 12 | palmer
# Processing Record 22 of Set 12 | bangkok
# Processing Record 23 of Set 12 | sabadell
# Processing Record 24 of Set 12 | nchelenge
# Processing Record 25 of Set 12 | soe
# Processing Record 26 of Set 12 | luanda
# Processing Record 27 of Set 12 | sinnamary
# Processing Record 28 of Set 12 | ust-barguzin
# Processing Record 29 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 30 of Set 12 | new bern
# Processing Record 31 of Set 12 | saryg-sep
# Processing Record 32 of Set 12 | astipalaia
# City not found. Skipping...
# Processing Record 33 of Set 12 | campestre
# Processing Record 34 of Set 12 | gravdal
# Processing Record 35 of Set 12 | naze
# Processing Record 36 of Set 12 | poim
# Processing Record 37 of Set 12 | calamar
# Processing Record 38 of Set 12 | kayiry
# Processing Record 39 of Set 12 | bitung
# Processing Record 40 of Set 12 | vestmannaeyjar
# Processing Record 41 of Set 12 | slonim
# Processing Record 42 of Set 12 | nhulunbuy
# Processing Record 43 of Set 12 | virginia beach
# Processing Record 44 of Set 12 | puerto madryn
# Processing Record 45 of Set 12 | aloleng
# Processing Record 46 of Set 12 | yining
# Processing Record 47 of Set 12 | abu zabad
# Processing Record 48 of Set 12 | angoram
# Processing Record 49 of Set 12 | byron bay
# Processing Record 50 of Set 12 | kuala kedah
# Processing Record 1 of Set 13 | farafenni
# Processing Record 2 of Set 13 | maniitsoq
# Processing Record 3 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 4 of Set 13 | aljezur
# Processing Record 5 of Set 13 | ankpa
# Processing Record 6 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 7 of Set 13 | jiaonan
# Processing Record 8 of Set 13 | clarence town
# Processing Record 9 of Set 13 | asau
# Processing Record 10 of Set 13 | svetlogorsk
# Processing Record 11 of Set 13 | tahta
# Processing Record 12 of Set 13 | oksfjord
# Processing Record 13 of Set 13 | saurimo
# Processing Record 14 of Set 13 | riviere-au-renard
# Processing Record 15 of Set 13 | gari
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 564

# %%
# convert list of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp      Current Description  \
# 0       busselton -33.65  115.33     53.01            broken clouds
# 1            chuy -33.70  -53.46     42.94         scattered clouds
# 2      zhezkazgan  47.80   67.71     78.80            broken clouds
# 3  severo-kurilsk  50.68  156.12     51.71          overcast clouds
# 4      nanortalik  60.14  -45.24     47.48          overcast clouds
# 5        klaksvik  62.23   -6.59     50.00          overcast clouds
# 6         rzhaksa  52.13   42.03     79.50                clear sky
# 7          albany  42.60  -73.97     75.00     heavy intensity rain
# 8         ushuaia -54.80  -68.30     33.80  heavy intensity drizzle
# 9          castro -24.79  -50.01     66.33                clear sky
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0           0.00              0        84          80        7.92      AU
# 1           0.00              0        76          33       11.59      UY
# 2           0.00              0        31          75       17.90      KZ
# 3           0.00              0        89         100       17.38      RU
# 4           0.00              0        92          99        4.88      GL
# 5           0.00              0       100         100       17.22      FO
# 6           0.00              0        40           0        5.59      RU
# 7           5.59              0        83          29        4.70      US
# 8           0.00              0        86          75       31.09      AR
# 9           0.00              0        69           0       10.18      BR

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 
                    'Cloudiness', 'Wind Speed', 'Current Description', 
                    'Rain (inches)', 'Snow (inches)']

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       busselton      AU -33.65  115.33     53.01        84          80
# 1            chuy      UY -33.70  -53.46     42.94        76          33
# 2      zhezkazgan      KZ  47.80   67.71     78.80        31          75
# 3  severo-kurilsk      RU  50.68  156.12     51.71        89         100
# 4      nanortalik      GL  60.14  -45.24     47.48        92          99
# 5        klaksvik      FO  62.23   -6.59     50.00       100         100
# 6         rzhaksa      RU  52.13   42.03     79.50        40           0
# 7          albany      US  42.60  -73.97     75.00        83          29
# 8         ushuaia      AR -54.80  -68.30     33.80        86          75
# 9          castro      BR -24.79  -50.01     66.33        69           0
#
#    Wind Speed      Current Description  Rain (inches)  Snow (inches)
# 0        7.92            broken clouds           0.00              0
# 1       11.59         scattered clouds           0.00              0
# 2       17.90            broken clouds           0.00              0
# 3       17.38          overcast clouds           0.00              0
# 4        4.88          overcast clouds           0.00              0
# 5       17.22          overcast clouds           0.00              0
# 6        5.59                clear sky           0.00              0
# 7        4.70     heavy intensity rain           5.59              0
# 8       31.09  heavy intensity drizzle           0.00              0
# 9       10.18                clear sky           0.00              0

# %%
raining_cities = city_data_df.loc[city_data_df['Rain (inches)'] > 0]
raining_cities.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 7       albany      US  42.60  -73.97     75.00        83          29
# 25        peno      RU  56.93   32.74     74.26        81          97
# 39  butaritari      KI   3.07  172.79     82.31        80         100
# 47     caramay      PH  10.18  119.24     80.19        80         100
# 50        teya      RU  60.38   92.63     66.70        64          71
#
#     Wind Speed   Current Description  Rain (inches)  Snow (inches)
# 7         4.70  heavy intensity rain           5.59              0
# 25        7.31         moderate rain           1.06              0
# 39       18.79         moderate rain           3.35              0
# 47        2.91            light rain           0.72              0
# 50        2.21            light rain           0.27              0

# %%
snowing_cities = city_data_df.loc[city_data_df['Snow (inches)'] > 0]
snowing_cities
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %%
# Create the output file (CSV).
output_data_file = 'challenge_data/WeatherPy_database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
